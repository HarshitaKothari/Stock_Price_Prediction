# %% [markdown]
# NESTLE STOCK PREDICTION

# %% [markdown]
# **DATA CLEANING**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/nestle.csv')

# %%
df.head()
# Out:
#         Date  Open Price  High_Price  Low Price  Close Price          WAP  \
# 0  21-Apr-22    18150.00    18572.95   17772.90     18205.80  18130.18344
# 1  20-Apr-22    18100.10    18415.00   18017.15     18313.70  18295.55907
# 2  19-Apr-22    18470.05    18718.00   17845.60     17943.15  18355.09332
# 3  18-Apr-22    18294.50    18684.50   18294.50     18549.85  18511.22460
# 4  13-Apr-22    18371.20    18549.30   18248.25     18343.90  18388.96783
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0          4590           1770              83217542                 950.0
# 1          6069           1321             111035748                4677.0
# 2          2904            716              53303191                1619.0
# 3          1496            586              27692792                 557.0
# 4          1150            550              21147313                 573.0
#
#    % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open
# ...

# %%
df.tail()
# Out:
#            Date  Open Price  High_Price  Low Price  Close Price          WAP  \
# 2548  06-Jan-12      4114.0      4160.0     4076.0      4143.25  4129.486321
# 2549  05-Jan-12      4118.0      4126.9     4080.0      4101.85  4106.848723
# 2550  04-Jan-12      4100.0      4125.0     4081.4      4120.60  4105.106055
# 2551  03-Jan-12      4061.0      4110.1     4060.1      4095.35  4091.474315
# 2552  02-Jan-12      4139.9      4139.9     4044.0      4070.35  4085.640979
#
#       No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 2548          3107            444              12830314                2069.0
# 2549          1018            270               4180772                 357.0
# 2550          2857            247              11728288                2312.0
# 2551          5003            886              20469646                2817.0
# 2552          7760           1132              31704574                5776.0
#
# ...

# %%
df.shape
# Out:
# (2553, 13)

# %%
df.size
# Out:
# 33189

# %%
df.describe()
# Out:
#          Open Price    High_Price     Low Price   Close Price           WAP  \
# count   2553.000000   2553.000000   2553.000000   2553.000000   2553.000000
# mean    9338.023188   9429.710419   9226.855934   9324.960556   9327.503179
# std     4940.554627   4986.783271   4878.971233   4932.776537   4929.373728
# min     3970.000000   3995.000000   3930.000000   3942.450000   3936.768632
# 25%     5391.000000   5445.000000   5327.200000   5383.500000   5385.347807
# 50%     6804.000000   6868.900000   6747.300000   6809.950000   6813.150538
# 75%    13299.950000  13690.950000  12850.000000  13455.450000  13387.505380
# max    20452.000000  20599.950000  20243.800000  20439.450000  20417.372400
#
#         No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# count    2553.000000    2553.000000          2.553000e+03
# mean     5521.380337    1004.099491          4.761923e+07
# std     10416.942384    1137.547557          8.502888e+07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2553 entries, 0 to 2552
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2553 non-null   object
#  1   Open Price                 2553 non-null   float64
#  2   High_Price                 2553 non-null   float64
#  3   Low Price                  2553 non-null   float64
#  4   Close Price                2553 non-null   float64
#  5   WAP                        2553 non-null   float64
#  6   No.of Shares               2553 non-null   int64
#  7   No. of Trades              2553 non-null   int64
#  8   Total Turnover (Rs.)       2553 non-null   int64
#  9   Deliverable Quantity       2551 non-null   float64
#  10  % Deli. Qty to Traded Qty  2551 non-null   float64
#  11  Spread High-Low            2553 non-null   float64
#  12  Spread Close-Open          2553 non-null   float64
# ...

# %%
df.corr()
# Out:
#                            Open Price  High_Price  Low Price  Close Price  \
# Open Price                   1.000000    0.999722   0.999701     0.999490
# High_Price                   0.999722    1.000000   0.999610     0.999793
# Low Price                    0.999701    0.999610   1.000000     0.999761
# Close Price                  0.999490    0.999793   0.999761     1.000000
# WAP                          0.999693    0.999879   0.999858     0.999927
# No.of Shares                -0.076134   -0.073740  -0.078191    -0.075764
# No. of Trades                0.155587    0.162156   0.150214     0.156813
# Total Turnover (Rs.)         0.191480    0.194465   0.188937     0.191751
# Deliverable Quantity        -0.093000   -0.092403  -0.093886    -0.093174
# % Deli. Qty to Traded Qty   -0.246738   -0.248603  -0.245208    -0.246861
# Spread High-Low              0.616536    0.627006   0.604996     0.616866
# Spread Close-Open           -0.065212   -0.047052  -0.047372    -0.033314
#
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True,linecolor='blue',cmap='Greens')
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Date                         0
# Open Price                   0
# High_Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         2
# % Deli. Qty to Traded Qty    2
# Spread High-Low              0
# Spread Close-Open            0
# dtype: int64

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='Open Price',data=df,orient='h');

# %% [markdown]
# there are no outliers

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='High_Price',data=df,orient='h')
# Out:
# <Axes: xlabel='High_Price'>

# %% [markdown]
# there are no outliers

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='Low Price',data=df,orient='h');

# %% [markdown]
# So, from the above graph we can conclude that there are no outliers

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='Close Price',data=df,orient='h')
# Out:
# <Axes: xlabel='Close Price'>

# %% [markdown]
# So ,From the above graph we can conclude that there are no outliers

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='WAP',data=df,orient='h');

# %% [markdown]
# So, from the above graph we can conclude that there are no outliers.

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Day']=df['Date'].dt.weekday
df['Month']=df['Date'].dt.month
df['Year']=df['Date'].dt.year

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df['Day'].value_counts()
# Out:
# 1    513
# 2    512
# 3    509
# 0    509
# 4    498
# 5      9
# 6      3
# Name: Day, dtype: int64

# %%
days = {1:'Tuesday',0:'Monday',3:'Thursday',2:'Wednesday',4: 'Friday',5:'Saturday',6:'Sunday'}
df['Day'] = df['Day'].map(days)

# %%
sns.lineplot(data=df, x="Year", y="High_Price");

# %%
sns.lineplot(data=df, x="Year", y="No. of Trades");

# %%
sns.lineplot(data=df,x='Month',y='No. of Trades');

# %%
sns.lineplot(data=df,x='Month',y='High_Price');

# %% [markdown]
# **TRENDS**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.filters.hp_filter import hpfilter

data = pd.read_csv(r'/content/nestle.csv', index_col=0, parse_dates=True)

print(data.head())
High_cycle, High_trend = hpfilter(data['High_Price'], lamb=6.25)

plt.figure(figsize=(15, 6))
High_trend.plot()
plt.title('Trend Component of High_Price')
plt.xlabel('Year.')
plt.ylabel('High_Price')
plt.show()
# Out:
#             Open Price  High_Price  Low Price  Close Price          WAP  \
# Date
# 2022-04-21    18150.00    18572.95   17772.90     18205.80  18130.18344
# 2022-04-20    18100.10    18415.00   18017.15     18313.70  18295.55907
# 2022-04-19    18470.05    18718.00   17845.60     17943.15  18355.09332
# 2022-04-18    18294.50    18684.50   18294.50     18549.85  18511.22460
# 2022-04-13    18371.20    18549.30   18248.25     18343.90  18388.96783
#
#             No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# Date
# 2022-04-21          4590           1770              83217542
# 2022-04-20          6069           1321             111035748
# 2022-04-19          2904            716              53303191
# 2022-04-18          1496            586              27692792
# 2022-04-13          1150            550              21147313
#
#             Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# Date
# ...

# %% [markdown]
# The above graph represents trend component of high_price.Trend is a pattern in data that shows the movement of a series to relatively higher or lower values over a long period of time.The graph explains that there is an increase in trend component with increase in  time.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
detrended = signal.detrend(data.High_Price.values)
plt.figure(figsize=(15,6))
plt.plot(detrended)
plt.xlabel('High_Price')
plt.ylabel('frequency')
plt.title('Detrending using Scipy Signal', fontsize=16)
plt.show()

# %% [markdown]
# The plotted graph shows the result of detrending the High_Price data using the signal.detrend function from SciPy. It aims to remove the trend component, allowing for a clearer view of potential deviations or patterns in the High_Price data. The X-axis represents the High_Price values and the data is detrended based on the High_Price values themselves.The Y-axis represents the frequency of the detrended data.The SciPy signal.detrend function aims to remove the trend from the High_Price data, making it easier to identify patterns or irregularities that might not be apparent when a trend is present.The resulting plot shows the detrended High_Price data. Peaks in the data indicate significant deviations from the overall trend. These deviations could be due to seasonality, or other events affecting High_Price.

# %% [markdown]
# **SEASONALITY**

# %%
from pandas.plotting import autocorrelation_plot
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(15,6)})
autocorrelation_plot(data.High_Price.tolist())
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# If the autocorrelation value is close to 1, it indicates a strong positive correlation between the time series and its lagged values at that lag.If the autocorrelation value is close to -1, it indicates a strong negative correlation. In this the autocorrelation plot is generated for the 'High_Price' column of the 'df' DataFrame, which likely represents the high prices of a stocks over time. The plot can help identify whether there are any significant autocorrelation patterns at various lags, which can be useful for time series analysis and forecasting.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
df=data
result_mul= seasonal_decompose(df['High_Price'], model='multiplicative', extrapolate_trend='freq', period=2)
deseason= df['High_Price'] -result_mul.seasonal
plt.figure(figsize=(15,6))
plt.plot(deseason)
plt.title('Deseasoning using seasonal_decompose', fontsize=16)
plt.xlabel('Year')
plt.ylabel('High_Price')
plt.show()

# %% [markdown]
# Plotting the deseasoned time series data.The vertical axis (Y-axis) represents the values of the 'High_Price' column of the original time series data.The horizontal axis (X-axis) typically represents time or years, indicating the progression of time over the dataset's duration.Here , we have used model as multiplicative.The graph is that it shows the underlying trend and irregular (non-seasonal) component of the original time series data. The seasonal component has been removed using the seasonal_decompose function, and you're left with non-seasonal components.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
result_mul= seasonal_decompose(df['High_Price'], model='additive', extrapolate_trend='freq', period=2)
deseason= df['High_Price'] -result_mul.seasonal
plt.figure(figsize=(15,6))
plt.plot(deseason)
plt.title('Deseasoning using seasonal_decompose', fontsize=16)
plt.xlabel('Year')
plt.ylabel('High_Price')
plt.show()

# %% [markdown]
# Plotting the deseasoned time series data.The vertical axis (Y-axis) represents the values of the 'High_Price' column of the original time series data.The horizontal axis (X-axis) typically represents time or years, indicating the progression of time over the dataset's duration.Here , we have used model as addititive.The graph is that it shows the underlying trend and irregular (non-seasonal) component of the original time series data. The seasonal component has been removed using the seasonal_decompose function, and you're left with non-seasonal components.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
#df = pd.read_csv(r'C:\Users\user\Downloads\nestle.csv', index_col=0,parse_dates=True)
result = seasonal_decompose(df['High_Price'], model='mul', extrapolate_trend='freq', period=2)
result.plot();

# %% [markdown]
# It uses Multiplicative model.The top subplot shows the observed data, which is the original time series.The second subplot shows the estimated trend component after deseasoning.The third subplot shows the estimated seasonal component. The fourth subplot shows the estimated residual component, which represents the noise or irregularity in the data after removing the trend and seasonal components.The subplots help us to visualize the different aspects of the time series data, making it easier to analyze trends and seasonality patterns, as well as identify any irregularities or noise in the data.

# %%
result = seasonal_decompose(df['High_Price'], model='add', extrapolate_trend='freq', period=2)
result.plot();

# %% [markdown]
# It uses Additive model.The top subplot shows the observed data, which is the original time series.The second subplot shows the estimated trend component after deseasoning.The third subplot shows the estimated seasonal component. The fourth subplot shows the estimated residual component, which represents the noise or irregularity in the data after removing the trend and seasonal components.The subplots help us to visualize the different aspects of the time series data, making it easier to analyze trends and seasonality patterns, as well as identify any irregularities or noise in the data.

# %%
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose as sm
#Simulating time series components

# setting the range of time series
T_Series = df

#create the trend component
Trend = T_Series * 2.75

#plot the trend
plt.plot(T_Series.High_Price, Trend, 'c.')
plt.title("Trend against Time")
# Out:
# Text(0.5, 1.0, 'Trend against Time')

# %% [markdown]
# the points on the graph form a clear, upward-sloping pattern, it indicates a positive trend where the 'Trend' component is consistently higher than the original 'High_Price' values.If the points form a downward-sloping pattern, it indicates a negative trend.If the points are randomly scattered, there may be no discernible trend.The trend is created by scaling the original data by a factor of 2.75, we would expect the 'Trend' component to be consistently higher than the original 'High' values, resulting in an upward-sloping pattern on the graph.

# %%
# creating the seasonality component
seasonality = 10 + np.sin(T_Series) * 10 #The sin function as it is the function that can yield those seasonal fluctuations of time series in the best way.

#plot the seasonality trend
plt.plot(T_Series.High_Price,  seasonality, 'b-.')
plt.title("Seasonality against Time")
# Out:
# Text(0.5, 1.0, 'Seasonality against Time')

# %% [markdown]
# The seasonality component is generated using the sine function, which creates periodic fluctuations. These fluctuations are typically characterized by a regular pattern that repeats over time.The baseline value of 10 added to the sine function's output sets the minimum value of the seasonality component, and scaling it by 10 controls the amplitude (or height) of the fluctuations.If the sine function results in values between -1 and 1, then the seasonality component will fluctuate between 0 and 20.The dashed blue line in the graph represents the seasonality component, and you would expect to see regular oscillations over time.The output graph illustrates how the simulated seasonality component behaves over time when added to the original 'High_Price' values.

# %%
#creating the residual component
np.random.seed(10)  # for result reproducibility
residual = np.random.normal(loc=0.0, scale=1, size=len(T_Series)) #Draw random samples from a normal (Gaussian) distribution. loc is the mean, scale is standard deviation

#plot the residual component
plt.plot(T_Series.High_Price, residual, 'r-.')
plt.title("Residuals against Time")
# Out:
# Text(0.5, 1.0, 'Residuals against Time')

# %% [markdown]
# The output graph shows how the simulated residual component relates to the original 'High_Price' values from the 'T_Series.' Each point on the graph corresponds to a data point in the 'T_Series' on the x-axis and the corresponding residual value on the y-axis.The residual component is generated as random noise drawn from a normal distribution with a mean of 0 and a standard deviation of 1. This means that the residuals are centered around 0 and have a spread defined by the standard deviation.The red dash-dot line in the graph represents the residual component. Since it's generated randomly, there is no discernible pattern or trend in the residual component.The output graph illustrates the random and unstructured nature of the simulated residual component.

# %%
# Assuming Trend, seasonality, and residual are defined elsewhere in your code

# Create an additive model of our time series
additive_Tmodel = Trend + seasonality + residual

# Plot the additive model
plt.plot(T_Series.High_Price, additive_Tmodel, 'k.')
plt.title("Additive Time Series")
plt.show()  # Don't forget to show the plot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-f548aebf13da> in <cell line: 4>()
#       2
#       3 # Create an additive model of our time series
# ----> 4 additive_Tmodel = Trend + seasonality + residual
#       5
#       6 # Plot the additive model
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __add__(self, other)
#     100     @unpack_zerodim_and_defer("__add__")
#     101     def __add__(self, other):
# --> 102         return self._arith_method(other, operator.add)
#     103
#     104     @unpack_zerodim_and_defer("__radd__")
#
# ...

# %% [markdown]
# **DATA SMOOTHENING**

# %%
from statsmodels.tsa.api import SimpleExpSmoothing
import pandas as pd
import numpy as np
from sklearn import metrics

# %%
#Making a copy of the data for High_Price column for train/split
X = df['High_Price']
test = X.iloc[-30:] #Data expected for last 30 days
train = X.iloc[:-30] #Last 30 days to evaluate prediction

# %%
#Function for calculating evaluation metrics to understand how far off our forecasts are against the actuals
#Closer to 0 better the model
#RMSE and MAPE are notable statistics measures used to check the accurcy of forecasting model.

def timeseries_evaluation_metrics_func(y_true, y_pred):

    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}') #how close a regression line is to a set of points.
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}') # average magnitude of the errors in a set of predictions.
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}') #square root of the avg of squared diff bet pred and actual obs
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}') #statistical measure of how accurate a forecast is.
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n') #proportion of variance in dependent variable by the independent variable

# %%
resu = []
temp_df = pd.DataFrame()
for i in [0 , 0.10, 0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80, 0.90,1]:
    print(f'Fitting for smoothing level= {i}')
    fit_v = SimpleExpSmoothing(np.asarray(train)).fit(i)
    fcst_pred_v= fit_v.forecast(30)
    timeseries_evaluation_metrics_func(test,fcst_pred_v)
    rmse = np.sqrt(metrics.mean_squared_error(test, fcst_pred_v))
    df3 = {'smoothing parameter':i, 'RMSE': rmse}
    temp_df = temp_df.append(df3, ignore_index=True)
temp_df.sort_values(by=['RMSE'])
# Out:
# Fitting for smoothing level= 0
# Evaluation metric results:-
# MSE is : 207150337.35625008
# MAE is : 14392.391666666666
# RMSE is : 14392.718205962698
# MAPE is : 344.5085095807939
# R2 is : -22037.51366826176
#
# Fitting for smoothing level= 0.1
# Evaluation metric results:-
# MSE is : 80360.3062499731
# MAE is : 266.3847531974835
# RMSE is : 283.4789344024933
# MAPE is : 6.429191032357743
# R2 is : -7.549451235650128
#
# Fitting for smoothing level= 0.2
# Evaluation metric results:-
# MSE is : 63827.0780289951
# MAE is : 233.2972535524287
# RMSE is : 252.64021459180861
# MAPE is : 5.637304167159788
# R2 is : -5.790497903597922
#
# Fitting for smoothing level= 0.3
# Evaluation metric results:-
# MSE is : 58210.45095820611
# MAE is : 220.93207427695333
# RMSE is : 241.26842097175938
# MAPE is : 5.341366935301581
# R2 is : -5.1929506630340025
#
# Fitting for smoothing level= 0.4
# Evaluation metric results:-
# MSE is : 53869.46598431466
# MAE is : 210.87910392076728
# ...

# %%
#using values from grid search
fitSES = SimpleExpSmoothing(np.asarray(train)).fit( smoothing_level = 1.0,optimized= False)
fcst_gs_pred = fitSES.forecast(30)
timeseries_evaluation_metrics_func(test,fcst_gs_pred)
# Out:
# Evaluation metric results:-
# MSE is : 31732.28125000001
# MAE is : 149.77500000000003
# RMSE is : 178.13556986183306
# MAPE is : 3.638068287620517
# R2 is : -2.3759651226179943

# %%
#Automated smoothing_level
fitSESauto = SimpleExpSmoothing(np.asarray(train)).fit( optimized= True, use_brute = True)
fcst_auto_pred = fitSESauto.forecast(30)
timeseries_evaluation_metrics_func(test,fcst_auto_pred)
# Out:
# Evaluation metric results:-
# MSE is : 31868.757195687547
# MAE is : 150.20052904838295
# RMSE is : 178.51822650835277
# MAPE is : 3.6482788158914157
# R2 is : -2.390484659649938

# %%
fitSESauto.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        SimpleExpSmoothing Model Results
# ...
# Dep. Variable:                  endog   No. Observations:                 2523
# Model:             SimpleExpSmoothing   SSE                       54655890.727
# Optimized:                       True   AIC                          25192.026
# Trend:                           None   BIC                          25203.693
# Seasonal:                        None   AICC                         25192.042
# Seasonal Periods:                None   Date:                 Sun, 03 Dec 2023
# Box-Cox:                        False   Time:                         10:59:26
# Box-Cox Coeff.:                  None
# ...
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.9950000                alpha                 True
# ...

# %%
df_fcst_gs_pred = pd.DataFrame(fcst_gs_pred, columns=['High_Price_grid_Search'])
df_fcst_gs_pred["new_index"] = range(1229, 1259)
df_fcst_gs_pred = df_fcst_gs_pred.set_index("new_index")

# %%
df_fcst_auto_pred = pd.DataFrame(fcst_auto_pred, columns=['High_Price_auto_search'])
df_fcst_auto_pred["new_index"] = range(1229, 1259)
df_fcst_auto_pred = df_fcst_auto_pred.set_index("new_index")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = [16,9]
plt.plot( train, label='Train')
plt.plot(test, label='Test')
plt.plot(df_fcst_auto_pred, label='Simple Exponential Smoothing using optimized =True')
plt.plot(df_fcst_gs_pred, label='Simple Exponential Smoothing using custom grid search')
plt.legend(loc='best')
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from timeit import default_timer as timer
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %%
df['High_Price'] = df['High_Price']

# %%
train = df.High_Price[0:-30]
test = df.High_Price[-30:]

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):

    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')

# %%
from sklearn.model_selection import ParameterGrid
#dampening - decreasing future time trends on a straight line(no trend)
param_grid = {'smoothing_level': [0.10, 0.20,.30,.40,.50,.60,.70,.80,.90], 'smoothing_slope':[0.10, 0.20,.30,.40,.50,.60,.70,.80,.90],
              'damping_slope': [0.10, 0.20,.30,.40,.50,.60,.70,.80,.90],'damped' : [True, False]}
pg = list(ParameterGrid(param_grid))

# %%
df_results_moni = pd.DataFrame(columns=['smoothing_level', 'smoothing_slope', 'damping_slope','damped','RMSE','r2'])
start = timer()
for a,b in enumerate(pg):
    smoothing_level = b.get('smoothing_level')
    smoothing_slope = b.get('smoothing_slope')
    damping_slope = b.get('damping_slope')
    damped = b.get('damped')
    print(smoothing_level, smoothing_slope, damping_slope,damped)
    fit1 = Holt(train,damped =damped ).fit(smoothing_level=smoothing_level, smoothing_slope=smoothing_slope, damping_slope = damping_slope ,optimized=False)
    #fit1.summary
    z = fit1.forecast(30)
    print(z)
    df_pred = pd.DataFrame(z, columns=['Forecasted_result'])
    RMSE = np.sqrt(metrics.mean_squared_error(test, df_pred.Forecasted_result))
    r2 = metrics.r2_score(test, df_pred.Forecasted_result)
    print( f' RMSE is {np.sqrt(metrics.mean_squared_error(test, df_pred.Forecasted_result))}')
    df_results_moni = df_results_moni.append({'smoothing_level' :smoothing_level, 'smoothing_slope':smoothing_slope, 'damping_slope' :damping_slope,'damped':damped,'RMSE': RMSE,'r2':r2}, ignore_index=True)
end = timer()
print(f' Total time taken to complete grid search in seconds: {(end - start)}')
# Out:
# Streaming output truncated to the last 5000 lines.
# 2539    4315.828424
# 2540    4310.469219
# 2541    4305.110015
# 2542    4299.750810
# 2543    4294.391606
# 2544    4289.032402
# 2545    4283.673197
# 2546    4278.313993
# 2547    4272.954788
# 2548    4267.595584
# 2549    4262.236379
# 2550    4256.877175
# 2551    4251.517970
# 2552    4246.158766
# dtype: float64
#  RMSE is 159.3580711726863
# 0.2 0.3 0.8 False
# 2523    4386.506914
# 2524    4377.796036
# 2525    4369.085158
# 2526    4360.374280
# 2527    4351.663401
# 2528    4342.952523
# 2529    4334.241645
# 2530    4325.530767
# 2531    4316.819889
# 2532    4308.109011
# 2533    4299.398132
# 2534    4290.687254
# 2535    4281.976376
# 2536    4273.265498
# 2537    4264.554620
# 2538    4255.843742
# 2539    4247.132864
# 2540    4238.421985
# 2541    4229.711107
# 2542    4221.000229
# 2543    4212.289351
# 2544    4203.578473
# 2545    4194.867595
# 2546    4186.156717
# 2547    4177.445838
# 2548    4168.734960
# ...

# %%
print(f' Below mentioned parameter gives least RMSE and r2')
df_results_moni.sort_values(by=['RMSE','r2']).head(1)
# Out:
#  Below mentioned parameter gives least RMSE and r2
#      smoothing_level  smoothing_slope  damping_slope damped       RMSE  \
# 689              0.5              0.6            0.9   True  62.560137
#
#            r2
# 689  0.583618

# %%
fit1 = Holt(train,damped =False ).fit(smoothing_level=0.9, smoothing_slope=0.6, damping_slope = 0.1 ,optimized=False)

# %%
Forecast_custom_pred = fit1.forecast(30)

# %%
fit1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               Holt Model Results
# ...
# Dep. Variable:             High_Price   No. Observations:                 2523
# Model:                           Holt   SSE                       73532190.566
# Optimized:                      False   AIC                          25944.515
# Trend:                       Additive   BIC                          25967.848
# Seasonal:                        None   AICC                         25944.549
# Seasonal Periods:                None   Date:                 Sun, 03 Dec 2023
# Box-Cox:                        False   Time:                         11:04:56
# Box-Cox Coeff.:                  None
# ...
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.9000000                alpha                False
# ...

# %%
timeseries_evaluation_metrics_func(test,Forecast_custom_pred)
# Out:
# Evaluation metric results:-
# MSE is : 743445.2692761063
# MAE is : 743.7984031949347
# RMSE is : 862.2327233851115
# MAPE is : 17.95358842673491
# R2 is : -78.09438593077756

# %%
# Automated Parameter
fitESAUTO = Holt(train).fit(optimized= True, use_brute = True)
fitESAUTO.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               Holt Model Results
# ...
# Dep. Variable:             High_Price   No. Observations:                 2523
# Model:                           Holt   SSE                       55946516.035
# Optimized:                       True   AIC                          25254.911
# Trend:                       Additive   BIC                          25278.244
# Seasonal:                        None   AICC                         25254.944
# Seasonal Periods:                None   Date:                 Sun, 03 Dec 2023
# Box-Cox:                        False   Time:                         11:04:56
# Box-Cox Coeff.:                  None
# ...
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.9950000                alpha                 True
# ...

# %%
fitESAUTOpred = fitESAUTO.forecast(30)
timeseries_evaluation_metrics_func(test,fitESAUTOpred)
# Out:
# Evaluation metric results:-
# MSE is : 7982.626111053416
# MAE is : 66.42643606328156
# RMSE is : 89.34554331948189
# MAPE is : 1.615971446030304
# R2 is : 0.15073652834789364

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = [16,9]
plt.plot( train, label='Train')
plt.plot(test, label='Test')
plt.plot(fitESAUTOpred, label='Automated grid search')
plt.plot(Forecast_custom_pred, label='Double Exponential Smoothing with custom grid search')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **DATA STATIONARY**

# %%
import pandas as pd
from matplotlib import pyplot
from statsmodels.tsa.stattools import adfuller

# %%
series = df
series['High_Price'].plot(figsize=(15,6))
pyplot.show()

# %%
def Augmented_Dickey_Fuller_Test_func(series , column_name):
    print (f'Results of Dickey-Fuller Test for column: {column_name}')
    dftest = adfuller(series, autolag='AIC') #AIC: Method to use when automatically determining the lag length among the values 0, 1, …, maxlag
    #The t-value measures the size of the difference relative to the variation in your sample data.
    #T is simply the calculated difference represented in units of standard error.
    #The greater the magnitude of T, the greater the evidence against the null hypothesis.

    dfoutput = pd.Series(dftest[0:4], index=['Test Statistics','p-value','Lags Used','No. of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value #Critical values for the ADF test for 1%, 5%, and 10% significance levels with the constant model are −3.43, −2.87, and −2.57, respectively.
    print (dfoutput)
    if dftest[1] <= 0.05:
        print("Conclusion:====>")
        print("Reject the null hypothesis")
        print("Data is stationary")
    else:
        print("Conclusion:====>")
        print("Fail to reject the null hypothesis")
        print("Data is non-stationary")

# %%
Augmented_Dickey_Fuller_Test_func(series['High_Price'], 'High_Price')
# Out:
# Results of Dickey-Fuller Test for column: High_Price
# Test Statistics               -1.284840
# p-value                        0.636079
# Lags Used                     24.000000
# No. of Observations Used    2528.000000
# Critical Value (1%)           -3.432939
# Critical Value (5%)           -2.862684
# Critical Value (10%)          -2.567379
# dtype: float64
# Conclusion:====>
# Fail to reject the null hypothesis
# Data is non-stationary

# %%
series['High_Price'].diff().plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# The Dickey-Fuller test was the first statistical test developed to test the null hypothesis that a unit root is present in an autoregressive model of a given time series.The graph shows after conducting dickey-fuller test which is for testing whether the data is stationary or not

# %%
Augmented_Dickey_Fuller_Test_func(series['High_Price'].diff().dropna(),'High_Price')
# Out:
# Results of Dickey-Fuller Test for column: High_Price
# Test Statistics            -1.142614e+01
# p-value                     6.688317e-21
# Lags Used                   2.300000e+01
# No. of Observations Used    2.528000e+03
# Critical Value (1%)        -3.432939e+00
# Critical Value (5%)        -2.862684e+00
# Critical Value (10%)       -2.567379e+00
# dtype: float64
# Conclusion:====>
# Reject the null hypothesis
# Data is stationary

# %% [markdown]
# **MODEL-ARIMA**

# %%
pip install pmdarima
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.5 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade statsmodels
# !pip install --upgrade statsmodels patsy
# !pip install statsmodels==0.12.2 patsy==0.5.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: patsy
#     Found existing installation: patsy 0.5.3
#     Uninstalling patsy-0.5.3:
#       Successfully uninstalled patsy-0.5.3
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 28.6 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Installing build dependencies ... error
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip install pmdarima
# !pip install --user pmdarima

# %%
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from pmdarima import auto_arima
from sklearn import metrics
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

warnings.filterwarnings("ignore")

# %%
df["High_Price"].plot(figsize=(15, 6))
plt.xlabel("Date")
plt.ylabel("High_Price")
plt.title("High Price of Nestle stocks")
plt.show()

# %%
plt.figure(1, figsize=(15,6))
plt.subplot(211)
df["High_Price"].hist()
plt.subplot(212)
df["High_Price"].plot(kind='kde')
plt.show()

# %%
X = df[['High_Price' ]]
train, test = X[0:-30], X[-30:]

# %%
stepwise_model = auto_arima(train,start_p=1, start_q=1,
    max_p=7, max_q=7, seasonal=False,
    d=None, trace=True,error_action='ignore',suppress_warnings=True, stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=32340.226, Time=1.92 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=32336.249, Time=0.51 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=32338.223, Time=0.83 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=32338.223, Time=0.80 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=32337.963, Time=0.18 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 4.333 seconds

# %%
stepwise_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                 2523
# Model:               SARIMAX(0, 1, 0)   Log Likelihood              -16166.124
# Date:                Sun, 03 Dec 2023   AIC                          32336.249
# Time:                        11:18:54   BIC                          32347.914
# Sample:                             0   HQIC                         32340.482
#                                - 2523
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -5.6475      2.969     -1.902      0.057     -11.466       0.171
# sigma2      2.164e+04    230.329     93.944      0.000    2.12e+04    2.21e+04
# ...
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):             16266.02
# ...

# %%
forecast,conf_int = stepwise_model.predict(n_periods=30,return_conf_int=True)
forecast = pd.DataFrame(forecast,columns=['High_Price_pred'])

# %%
df_conf = pd.DataFrame(conf_int,columns= ['Upper_bound','Lower_bound'])
df_conf["new_index"] = range(1229, 1259)
df_conf = df_conf.set_index("new_index")

# %%
forecast["new_index"] = range(1229, 1259)
forecast = forecast.set_index("new_index")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = [15,7]
plt.plot( train, label='Train ')
plt.plot(test, label='Test ')
plt.plot(forecast, label='Predicted ')
plt.plot(df_conf['Upper_bound'], label='Confidence Interval Upper bound ')
plt.plot(df_conf['Lower_bound'], label='Confidence Interval Lower bound ')
plt.legend(loc='best')
plt.show()

# %%
stepwise_model.plot_diagnostics();

# %%
forecast
# Out:
#            High_Price_pred
# new_index
# 1229           4324.352518
# 1230           4318.705036
# 1231           4313.057554
# 1232           4307.410071
# 1233           4301.762589
# 1234           4296.115107
# 1235           4290.467625
# 1236           4284.820143
# 1237           4279.172661
# 1238           4273.525178
# 1239           4267.877696
# 1240           4262.230214
# 1241           4256.582732
# 1242           4250.935250
# 1243           4245.287768
# 1244           4239.640285
# 1245           4233.992803
# 1246           4228.345321
# 1247           4222.697839
# 1248           4217.050357
# 1249           4211.402875
# 1250           4205.755393
# 1251           4200.107910
# 1252           4194.460428
# 1253           4188.812946
# 1254           4183.165464
# 1255           4177.517982
# 1256           4171.870500
# 1257           4166.223017
# 1258           4160.575535

# %% [markdown]
# **CONVOLUTIONAL MODEL**

# %%
import numpy as np
import pandas as pd
from numpy import array
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv1D, MaxPooling1D

# %%
def split_sequence(sequence,steps):
  X,y=list(),list()
  for start in range(len(sequence)):
    end_index = start + steps
    if end_index > len(sequence)-1:
      break
    sequence_x,sequence_y = sequence[start : end_index], sequence[end_index]
    X.append(sequence_x)
    y.append(sequence_y)
  return array(X),array(y)

# %%
def exp8(col_name):
    raw_sequence = df[col_name]
    # choose the number of time steps
    steps = 3
    # split into samples
    X, y = split_sequence(raw_sequence, steps)
    return X, y

# %%
X_data, y_data = exp8('High_Price')

print('The input sequence on which we will test our CNN Model: ')
print(df['High_Price'])
print("\n\n****************************************************************")
print('The features (X), lagged values of the time series, for our CNN Model')
print(X_data[:5])
print("\n\n****************************************************************")
print('The respective observed values (y) of the sequence for training in the CNN Model')
print(y_data)
print("****************************************************************\n\n")

# Reshape 2D input data to 3D input data
features = 1
X_data = X_data.reshape((X_data.shape[0], X_data.shape[1], features))

print('After reshaping, the shape of the input X')
print(X_data.shape)
print("\n\n*************************************************")
print("*************************************************")
print('The final form of input feature matrix X')
print(X_data[:5])
print("\n\n*************************************************")
print("*************************************************")
print('Feature matrix X is ready for input to the CNN Model')
print("*************************************************\n\n")

# Defining model architecture
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(3, features)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Fit the model
model.fit(X_data, y_data, epochs=100, verbose=1)

# Predict
x_input = array(df['High_Price'][-3:])
x_input = x_input.reshape((1, 3, features))
y_pred = model.predict(x_input, verbose=0)

print("*************************************************")
print("The next predicted value is ")
print(y_pred)
print("The next true value is ")
print(df['High_Price'].iloc[-1])
print("*************************************************")
# Out:
# The input sequence on which we will test our CNN Model:
# Date
# 2022-04-21    18572.95
# 2022-04-20    18415.00
# 2022-04-19    18718.00
# 2022-04-18    18684.50
# 2022-04-13    18549.30
#                 ...
# 2012-01-06     4160.00
# 2012-01-05     4126.90
# 2012-01-04     4125.00
# 2012-01-03     4110.10
# 2012-01-02     4139.90
# Name: High_Price, Length: 2553, dtype: float64
#
#
# ****************************************************************
# The features (X), lagged values of the time series, for our CNN Model
# [[18572.95 18415.   18718.  ]
#  [18415.   18718.   18684.5 ]
#  [18718.   18684.5  18549.3 ]
#  [18684.5  18549.3  18497.  ]
#  [18549.3  18497.   18518.35]]
#
#
# ****************************************************************
# The respective observed values (y) of the sequence for training in the CNN Model
# [18684.5 18549.3 18497.  ...  4125.   4110.1  4139.9]
# ****************************************************************
#
#
# ...

# %%
exp8("High_Price")
# Out:
# (array([[18572.95, 18415.  , 18718.  ],
#         [18415.  , 18718.  , 18684.5 ],
#         [18718.  , 18684.5 , 18549.3 ],
#         ...,
#         [ 4146.95,  4160.  ,  4126.9 ],
#         [ 4160.  ,  4126.9 ,  4125.  ],
#         [ 4126.9 ,  4125.  ,  4110.1 ]]),
#  array([18684.5, 18549.3, 18497. , ...,  4125. ,  4110.1,  4139.9]))

# %%
import matplotlib.pyplot as plt
plt.plot(df['High_Price'], label='True Values', color='blue')
plt.scatter(len(df['High_Price']) - 1, y_pred, label='Predicted Value', color='red')
plt.legend()
plt.show()

# %%
exp8("Open Price")
# Out:
# (array([[18150.  , 18100.1 , 18470.05],
#         [18100.1 , 18470.05, 18294.5 ],
#         [18470.05, 18294.5 , 18371.2 ],
#         ...,
#         [ 4099.8 ,  4114.  ,  4118.  ],
#         [ 4114.  ,  4118.  ,  4100.  ],
#         [ 4118.  ,  4100.  ,  4061.  ]]),
#  array([18294.5, 18371.2, 18339. , ...,  4100. ,  4061. ,  4139.9]))

# %%
exp8("Close Price")
# Out:
# (array([[18205.8 , 18313.7 , 17943.15],
#         [18313.7 , 17943.15, 18549.85],
#         [17943.15, 18549.85, 18343.9 ],
#         ...,
#         [ 4125.  ,  4143.25,  4101.85],
#         [ 4143.25,  4101.85,  4120.6 ],
#         [ 4101.85,  4120.6 ,  4095.35]]),
#  array([18549.85, 18343.9 , 18430.  , ...,  4120.6 ,  4095.35,  4070.35]))

# %%
exp8("WAP")
# Out:
# (array([[18130.18344 , 18295.55907 , 18355.09332 ],
#         [18295.55907 , 18355.09332 , 18511.2246  ],
#         [18355.09332 , 18511.2246  , 18388.96783 ],
#         ...,
#         [ 4128.345238,  4129.486321,  4106.848723],
#         [ 4129.486321,  4106.848723,  4105.106055],
#         [ 4106.848723,  4105.106055,  4091.474315]]),
#  array([18511.2246  , 18388.96783 , 18390.222   , ...,  4105.106055,
#          4091.474315,  4085.640979]))

# %%
exp8("No. of Trades")
# Out:
# (array([[1770, 1321,  716],
#         [1321,  716,  586],
#         [ 716,  586,  550],
#         ...,
#         [  38,  444,  270],
#         [ 444,  270,  247],
#         [ 270,  247,  886]]),
#  array([ 586,  550,  537, ...,  247,  886, 1132]))

# %%
exp8("Total Turnover (Rs.)")
# Out:
# (array([[ 83217542, 111035748,  53303191],
#         [111035748,  53303191,  27692792],
#         [ 53303191,  27692792,  21147313],
#         ...,
#         [   346781,  12830314,   4180772],
#         [ 12830314,   4180772,  11728288],
#         [  4180772,  11728288,  20469646]]),
#  array([27692792, 21147313, 36780444, ..., 11728288, 20469646, 31704574]))

# %%
exp8("Deliverable Quantity")
# Out:
# (array([[ 950., 4677., 1619.],
#         [4677., 1619.,  557.],
#         [1619.,  557.,  573.],
#         ...,
#         [  44., 2069.,  357.],
#         [2069.,  357., 2312.],
#         [ 357., 2312., 2817.]]),
#  array([ 557.,  573., 1412., ..., 2312., 2817., 5776.]))

# %%
exp8("% Deli. Qty to Traded Qty")
# Out:
# (array([[20.7 , 77.06, 55.75],
#         [77.06, 55.75, 37.23],
#         [55.75, 37.23, 49.83],
#         ...,
#         [52.38, 66.59, 35.07],
#         [66.59, 35.07, 80.92],
#         [35.07, 80.92, 56.31]]),
#  array([37.23, 49.83, 70.6 , ..., 80.92, 56.31, 74.43]))

# %%
exp8("Spread High-Low")
# Out:
# (array([[800.05, 397.85, 872.4 ],
#         [397.85, 872.4 , 390.  ],
#         [872.4 , 390.  , 301.05],
#         ...,
#         [ 47.15,  84.  ,  46.9 ],
#         [ 84.  ,  46.9 ,  43.6 ],
#         [ 46.9 ,  43.6 ,  50.  ]]),
#  array([390.  , 301.05, 280.7 , ...,  43.6 ,  50.  ,  95.9 ]))

# %%
exp8("Spread Close-Open")
# Out:
# (array([[  55.8 ,  213.6 , -526.9 ],
#         [ 213.6 , -526.9 ,  255.35],
#         [-526.9 ,  255.35,  -27.3 ],
#         ...,
#         [  25.2 ,   29.25,  -16.15],
#         [  29.25,  -16.15,   20.6 ],
#         [ -16.15,   20.6 ,   34.35]]),
#  array([255.35, -27.3 ,  91.  , ...,  20.6 ,  34.35, -69.55]))
